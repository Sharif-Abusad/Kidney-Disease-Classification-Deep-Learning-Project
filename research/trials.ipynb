# %%
import gdown

# %%
url = "https://drive.google.com/drive/folders/1yA4xt7YXCl2bIhj-DKWUHx5qpi_JBkbn?usp=sharing"

# %%
parts = url.replace("?", "/").split("/")
parts
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'drive',
#  'folders',
#  '1yA4xt7YXCl2bIhj-DKWUHx5qpi_JBkbn',
#  'usp=sharing']

# %%
file_id = parts[-2]
file_id
# Out:
# '1yA4xt7YXCl2bIhj-DKWUHx5qpi_JBkbn'

# %%
import gdown

file_id = "1yA4xt7YXCl2bIhj-DKWUHx5qpi_JBkbn"
url = f"https://drive.google.com/uc?id={file_id}"

gdown.download(url, "Kidney-CT-Scan-Data.zip", quiet=False)
# Out:
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File c:\Users\DELL\OneDrive\Desktop\Kidney-Disease-Classification-Deep-Learning-Project\venv\Lib\site-packages\gdown\download.py:313, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress, skip_download)
#     312 try:
# --> 313     url = get_url_from_gdrive_confirmation(res.text)
#     314 except FileURLRetrievalError as e:
#
# File c:\Users\DELL\OneDrive\Desktop\Kidney-Disease-Classification-Deep-Learning-Project\venv\Lib\site-packages\gdown\download.py:70, in get_url_from_gdrive_confirmation(contents)
#      69 if not url:
# ---> 70     raise FileURLRetrievalError(
#      71         "Cannot retrieve the public link of the file. "
#      72         "You may need to change the permission to "
# ...
